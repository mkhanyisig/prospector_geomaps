# %%
# load libraries
import pandas as pd
import csv
import json
from IPython.display import display
import time


#Goal: add mineral tags for each location

# %% [markdown]
# ## Load JSON file and create object

# %%
with open('mexico.json') as f:
  json_obj = json.load(f)
#print(type(json_obj))
print("****\nTesting \n****\n")
print("Total Locations: ",len(json_obj['features']))
print("\nGeometry:\n",json_obj['features'][0]['geometry'])
# Out:
# ****
# Testing
# ****
#
# Total Locations:  4763
#
# Geometry:
#  {'type': 'Point', 'coordinates': [-104.91717, 29.33356]}

# %% [markdown]
# ### Create and add tags

# %%
minerals=set()

i=0
for location in json_obj['features']: # first 10, replace for general later
    #print(location['properties']['commod1']," * ",location['properties']['commod2'],' * ',location['properties']['commod3'])
    min1=location['properties']['commod1']
    min2=location['properties']['commod2']
    min3=location['properties']['commod3']
    
    mineral_tags=set()
    
    print("\n***\n")
    # first tag
    if min1!=None:
        print(min1)    
        min1=min1.split(",")
        temp=[]
        for el in min1:
            el=el.replace(" ","")
            el=el.lower()
            temp.append(el) 
            mineral_tags.add(el)
        print(temp)
    # second tag
    if min2!=None:
        print(min2)    
        min2=min2.split(",")
        temp=[]
        for el in min2:
            el=el.replace(" ","")
            el=el.lower()
            temp.append(el) 
            mineral_tags.add(el)
        print(temp)
    # second tag
    if min3!=None:
        print(min3)    
        min3=min3.split(",")
        temp=[]
        for el in min3:
            el=el.replace(" ","")
            el=el.lower()
            temp.append(el) 
            mineral_tags.add(el)
        print(temp)
        
    print("Minerals: ",list(mineral_tags))
    mineral_tags=list(mineral_tags)
    json_obj['features'][i]['properties']['mineral_tags']=mineral_tags
    #print(json_obj['features'][i]['properties'])
    i+=1
# Out:
# ***
#
# Copper, Gold, Silver, Vanadium
# ['copper', 'gold', 'silver', 'vanadium']
# Minerals:  ['copper', 'gold', 'silver', 'vanadium']
#
# ***
#
# Lead, Zinc, Gold, Silver, Mercury, Vanadium
# ['lead', 'zinc', 'gold', 'silver', 'mercury', 'vanadium']
# Minerals:  ['vanadium', 'gold', 'lead', 'mercury', 'silver', 'zinc']
#
# ***
#
# Lead, Zinc, Silver, Vanadium
# ['lead', 'zinc', 'silver', 'vanadium']
# Minerals:  ['silver', 'zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Copper, Silver
# ['lead', 'zinc', 'copper', 'silver']
# Tin, Vanadium
# ['tin', 'vanadium']
# Minerals:  ['tin', 'vanadium', 'copper', 'lead', 'silver', 'zinc']
#
# ***
#
# Vanadium
# ['vanadium']
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['lead', 'silver', 'vanadium']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Lead, Zinc, Vanadium
# ['lead', 'zinc', 'vanadium']
# Minerals:  ['zinc', 'vanadium', 'lead']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Copper, Tungsten, Silver, Molybdenum, Gold
# ['copper', 'tungsten', 'silver', 'molybdenum', 'gold']
# Minerals:  ['molybdenum', 'tungsten', 'copper', 'gold', 'silver']
#
# ***
#
# Aluminum
# ['aluminum']
# Minerals:  ['aluminum']
#
# ***
#
# Gold, Copper, Silver
# ['gold', 'copper', 'silver']
# Wollastonite
# ['wollastonite']
# Minerals:  ['copper', 'gold', 'silver', 'wollastonite']
#
# ***
#
# Dolomite
# ['dolomite']
# Minerals:  ['dolomite']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Strontium
# ['strontium']
# Fluorine-Fluorite, Gypsum-Anhydrite
# ['fluorine-fluorite', 'gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite', 'strontium', 'fluorine-fluorite']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Pumice
# ['pumice']
# Minerals:  ['pumice']
#
# ***
#
# Kaolin
# ['kaolin']
# Minerals:  ['kaolin']
#
# ***
#
# Feldspar, Sand and Gravel, Construction
# ['feldspar', 'sandandgravel', 'construction']
# Minerals:  ['feldspar', 'construction', 'sandandgravel']
#
# ***
#
# Stone, Dimension
# ['stone', 'dimension']
# Minerals:  ['stone', 'dimension']
#
# ***
#
# Calcium
# ['calcium']
# Minerals:  ['calcium']
#
# ***
#
# Stone, Dimension
# ['stone', 'dimension']
# Minerals:  ['stone', 'dimension']
#
# ***
#
# Calcium
# ['calcium']
# Minerals:  ['calcium']
#
# ***
#
# Calcium
# ['calcium']
# Minerals:  ['calcium']
#
# ***
#
# Dolomite
# ['dolomite']
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'dolomite', 'limestone']
#
# ***
#
# Dolomite
# ['dolomite']
# Minerals:  ['dolomite']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Asbestos
# ['asbestos']
# Minerals:  ['asbestos']
#
# ***
#
# Asbestos
# ['asbestos']
# Minerals:  ['asbestos']
#
# ***
#
# Diatomite
# ['diatomite']
# Minerals:  ['diatomite']
#
# ***
#
# Diatomite
# ['diatomite']
# Minerals:  ['diatomite']
#
# ***
#
# Diatomite
# ['diatomite']
# Minerals:  ['diatomite']
#
# ***
#
# Diatomite
# ['diatomite']
# Minerals:  ['diatomite']
#
# ***
#
# Silica, Feldspar
# ['silica', 'feldspar']
# Minerals:  ['feldspar', 'silica']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Calcium
# ['calcium']
# Minerals:  ['calcium']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Fluorine-Fluorite, Gold, Silver
# ['fluorine-fluorite', 'gold', 'silver']
# Minerals:  ['gold', 'silver', 'fluorine-fluorite']
#
# ***
#
# Barium-Barite, Silver, Zinc
# ['barium-barite', 'silver', 'zinc']
# Lead
# ['lead']
# Manganese
# ['manganese']
# Minerals:  ['manganese', 'barium-barite', 'lead', 'silver', 'zinc']
#
# ***
#
# Volcanic Materials
# ['volcanicmaterials']
# Minerals:  ['volcanicmaterials']
#
# ***
#
# Silver, Gold, Fluorine-Fluorite
# ['silver', 'gold', 'fluorine-fluorite']
# Minerals:  ['gold', 'silver', 'fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Lead, Zinc, Silver
# ['lead', 'zinc', 'silver']
# Gold, Fluorine-Fluorite, Copper
# ['gold', 'fluorine-fluorite', 'copper']
# Minerals:  ['fluorine-fluorite', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Feldspar
# ['feldspar']
# Minerals:  ['feldspar']
#
# ***
#
# Limestone, High Calcium
# ['limestone', 'highcalcium']
# Minerals:  ['limestone', 'highcalcium']
#
# ***
#
# Stone
# ['stone']
# Minerals:  ['stone']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Diatomite
# ['diatomite']
# Minerals:  ['diatomite']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Quartz
# ['quartz']
# Minerals:  ['quartz']
#
# ***
#
# Zeolites
# ['zeolites']
# Minerals:  ['zeolites']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Limestone, High Calcium
# ['limestone', 'highcalcium']
# Minerals:  ['limestone', 'highcalcium']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Zeolites
# ['zeolites']
# Minerals:  ['zeolites']
#
# ***
#
# Zeolites
# ['zeolites']
# Minerals:  ['zeolites']
#
# ***
#
# Marble, Dimension
# ['marble', 'dimension']
# Minerals:  ['marble', 'dimension']
#
# ***
#
# Dolomite
# ['dolomite']
# Minerals:  ['dolomite']
#
# ***
#
# Silica, Quartz
# ['silica', 'quartz']
# Minerals:  ['quartz', 'silica']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Wollastonite
# ['wollastonite']
# Minerals:  ['wollastonite']
#
# ***
#
# Halite, Salt
# ['halite', 'salt']
# Minerals:  ['salt', 'halite']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Stone
# ['stone']
# Minerals:  ['stone']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Marble, Dimension
# ['marble', 'dimension']
# Minerals:  ['marble', 'dimension']
#
# ***
#
# Mica
# ['mica']
# Minerals:  ['mica']
#
# ***
#
# Quartz
# ['quartz']
# Minerals:  ['quartz']
#
# ***
#
# Wollastonite
# ['wollastonite']
# Minerals:  ['wollastonite']
#
# ***
#
# Stone
# ['stone']
# Minerals:  ['stone']
#
# ***
#
# Kaolin
# ['kaolin']
# Minerals:  ['kaolin']
#
# ***
#
# Stone
# ['stone']
# Minerals:  ['stone']
#
# ***
#
# Feldspar
# ['feldspar']
# Minerals:  ['feldspar']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Quartz, Silica
# ['quartz', 'silica']
# Minerals:  ['quartz', 'silica']
#
# ***
#
# Stone
# ['stone']
# Minerals:  ['stone']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Marble, Dimension
# ['marble', 'dimension']
# Minerals:  ['marble', 'dimension']
#
# ***
#
# Marble, Dimension
# ['marble', 'dimension']
# Minerals:  ['marble', 'dimension']
#
# ***
#
# Salt, Halite
# ['salt', 'halite']
# Minerals:  ['salt', 'halite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Talc-Soapstone
# ['talc-soapstone']
# Minerals:  ['talc-soapstone']
#
# ***
#
# Perlite
# ['perlite']
# Minerals:  ['perlite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Strontium
# ['strontium']
# Minerals:  ['strontium']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper, Tungsten
# ['copper', 'tungsten']
# Minerals:  ['copper', 'tungsten']
#
# ***
#
# Platinum
# ['platinum']
# Minerals:  ['platinum']
#
# ***
#
# Platinum
# ['platinum']
# Minerals:  ['platinum']
#
# ***
#
# Platinum
# ['platinum']
# Minerals:  ['platinum']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Palladium, Nickel, Platinum, Tellurium, Selenium
# ['palladium', 'nickel', 'platinum', 'tellurium', 'selenium']
# Minerals:  ['selenium', 'tellurium', 'nickel', 'gold', 'palladium', 'silver', 'platinum']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Zinc, Lead, Silver
# ['zinc', 'lead', 'silver']
# Minerals:  ['lead', 'silver', 'zinc']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Dolomite
# ['dolomite']
# Minerals:  ['dolomite']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Dolomite
# ['dolomite']
# Minerals:  ['dolomite']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Zinc
# ['zinc']
# Minerals:  ['zinc']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Zinc
# ['zinc']
# Minerals:  ['zinc']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Limestone, General
# ['limestone', 'general']
# Minerals:  ['general', 'limestone']
#
# ***
#
# Sand and Gravel, Construction
# ['sandandgravel', 'construction']
# Minerals:  ['construction', 'sandandgravel']
#
# ***
#
# Sand and Gravel, Construction
# ['sandandgravel', 'construction']
# Minerals:  ['construction', 'sandandgravel']
#
# ***
#
# Silver
# ['silver']
# Minerals:  ['silver']
#
# ***
#
# Silver, Copper, Gold
# ['silver', 'copper', 'gold']
# Minerals:  ['copper', 'gold', 'silver']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Quartz
# ['quartz']
# Minerals:  ['quartz']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['lead', 'zinc']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Tungsten, Molybdenum
# ['tungsten', 'molybdenum']
# Minerals:  ['molybdenum', 'tungsten']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper
# ['copper']
# Molybdenum, Silver
# ['molybdenum', 'silver']
# Minerals:  ['copper', 'molybdenum', 'silver']
#
# ***
#
# Cobalt, Sodium
# ['cobalt', 'sodium']
# Halite
# ['halite']
# Minerals:  ['cobalt', 'halite', 'sodium']
#
# ***
#
# Copper, Gold, Silver
# ['copper', 'gold', 'silver']
# Minerals:  ['copper', 'gold', 'silver']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Tungsten, Zinc
# ['tungsten', 'zinc']
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['lead', 'silver', 'zinc', 'tungsten']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Antimony
# ['antimony']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['copper', 'gold', 'barium-barite', 'antimony']
#
# ***
#
# Asbestos
# ['asbestos']
# Minerals:  ['asbestos']
#
# ***
#
# Copper, Silver
# ['copper', 'silver']
# Minerals:  ['copper', 'silver']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper, Lead
# ['copper', 'lead']
# Silver
# ['silver']
# Minerals:  ['copper', 'silver', 'lead']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Lead, Gold, Silver
# ['lead', 'gold', 'silver']
# Minerals:  ['gold', 'silver', 'lead']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Iron
# ['iron']
# Magnesite
# ['magnesite']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'magnesite', 'iron', 'sulfur']
#
# ***
#
# Copper, Molybdenum, Gold
# ['copper', 'molybdenum', 'gold']
# Minerals:  ['copper', 'gold', 'molybdenum']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Zinc, Silver
# ['zinc', 'silver']
# Minerals:  ['copper', 'molybdenum', 'silver', 'zinc']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Copper, Lead, Zinc
# ['copper', 'lead', 'zinc']
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Copper
# ['copper']
# Gold, Silver
# ['gold', 'silver']
# Lead, Tungsten, Zinc
# ['lead', 'tungsten', 'zinc']
# Minerals:  ['tungsten', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper, Molybdenum, Tungsten
# ['copper', 'molybdenum', 'tungsten']
# Silver, Gold
# ['silver', 'gold']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['molybdenum', 'tungsten', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Molybdenum
# ['molybdenum']
# Copper
# ['copper']
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['copper', 'molybdenum', 'lead', 'zinc']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Silver
# ['silver']
# Zinc, Lead, Copper
# ['zinc', 'lead', 'copper']
# Minerals:  ['lead', 'silver', 'copper', 'zinc']
#
# ***
#
# Copper
# ['copper']
# Molybdenum, Uranium
# ['molybdenum', 'uranium']
# Minerals:  ['copper', 'molybdenum', 'uranium']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Molybdenum, Copper
# ['molybdenum', 'copper']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Copper, Molybdenum, Tungsten
# ['copper', 'molybdenum', 'tungsten']
# Minerals:  ['copper', 'molybdenum', 'tungsten']
#
# ***
#
# Silver
# ['silver']
# Lead
# ['lead']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Molybdenum
# ['molybdenum']
# Minerals:  ['molybdenum']
#
# ***
#
# Copper
# ['copper']
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['copper', 'gold', 'silver']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper
# ['copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Gold
# ['gold']
# Copper, Iron
# ['copper', 'iron']
# Minerals:  ['copper', 'gold', 'iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Uranium, Tin
# ['uranium', 'tin']
# Minerals:  ['tin', 'fluorine-fluorite', 'gold', 'silver', 'uranium']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'gold', 'molybdenum', 'silver']
#
# ***
#
# Iron
# ['iron']
# Titanium, Metal, Manganese, Copper, Magnesite
# ['titanium', 'metal', 'manganese', 'copper', 'magnesite']
# Minerals:  ['manganese', 'iron', 'metal', 'copper', 'magnesite', 'titanium']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Lead, Silver, Gold, Copper
# ['lead', 'silver', 'gold', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper, Gold
# ['copper', 'gold']
# Iron
# ['iron']
# Minerals:  ['copper', 'gold', 'iron']
#
# ***
#
# Talc-Soapstone, Vermiculite
# ['talc-soapstone', 'vermiculite']
# Minerals:  ['vermiculite', 'talc-soapstone']
#
# ***
#
# Copper, Gold
# ['copper', 'gold']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Gold, Uranium
# ['gold', 'uranium']
# Lead, Zinc, Silver
# ['lead', 'zinc', 'silver']
# Minerals:  ['gold', 'uranium', 'lead', 'silver', 'zinc']
#
# ***
#
# Sodium
# ['sodium']
# Gold
# ['gold']
# Minerals:  ['gold', 'sodium']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Lead, Zinc, Silver
# ['lead', 'zinc', 'silver']
# Minerals:  ['silver', 'zinc', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Lead, Molybdenum
# ['lead', 'molybdenum']
# Minerals:  ['gold', 'molybdenum', 'silver', 'lead']
#
# ***
#
# Bromine, Halite
# ['bromine', 'halite']
# Minerals:  ['bromine', 'halite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Gold
# ['gold']
# Barium-Barite, Molybdenum, Graphite
# ['barium-barite', 'molybdenum', 'graphite']
# Minerals:  ['molybdenum', 'graphite', 'barium-barite', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper, Zinc, Silver
# ['copper', 'zinc', 'silver']
# Minerals:  ['copper', 'silver', 'zinc']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Lithium
# ['lithium']
# Ruthenium
# ['ruthenium']
# Minerals:  ['ruthenium', 'lithium']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper, Iron
# ['copper', 'iron']
# Sulfur, Silver, Gold
# ['sulfur', 'silver', 'gold']
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['iron', 'copper', 'gold', 'phosphorus-phosphates', 'sulfur', 'silver']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Gold
# ['gold']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'gold', 'zinc', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Copper
# ['copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur
# ['sulfur']
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'gold', 'iron']
#
# ***
#
# Sulfur
# ['sulfur']
# Minerals:  ['sulfur']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'gold', 'iron']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper, Zinc
# ['copper', 'zinc']
# Silver
# ['silver']
# Manganese, Lead, Cobalt
# ['manganese', 'lead', 'cobalt']
# Minerals:  ['manganese', 'copper', 'cobalt', 'lead', 'silver', 'zinc']
#
# ***
#
# Manganese
# ['manganese']
# Vanadium
# ['vanadium']
# Minerals:  ['manganese', 'vanadium']
#
# ***
#
# Chromium
# ['chromium']
# Minerals:  ['chromium']
#
# ***
#
# Halite
# ['halite']
# Minerals:  ['halite']
#
# ***
#
# Magnesite
# ['magnesite']
# Minerals:  ['magnesite']
#
# ***
#
# Magnesite
# ['magnesite']
# Minerals:  ['magnesite']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Asbestos
# ['asbestos']
# Minerals:  ['asbestos']
#
# ***
#
# Magnesite
# ['magnesite']
# Minerals:  ['magnesite']
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Tungsten
# ['tungsten']
# Minerals:  ['gold', 'silver', 'tungsten']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Tungsten
# ['tungsten']
# Minerals:  ['gold', 'silver', 'tungsten']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Zinc, Copper, Lead
# ['zinc', 'copper', 'lead']
# Minerals:  ['copper', 'lead', 'zinc']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Lead
# ['copper', 'lead']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite', 'silver', 'lead']
#
# ***
#
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Silver, Zinc, Gold
# ['silver', 'zinc', 'gold']
# Minerals:  ['gold', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Gold, Zinc, Lead, Copper
# ['gold', 'zinc', 'lead', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum', 'tungsten']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Copper, Lead, Zinc, Silver
# ['copper', 'lead', 'zinc', 'silver']
# Minerals:  ['copper', 'silver', 'zinc', 'lead']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Silver, Lead
# ['silver', 'lead']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Silver, Lead, Copper
# ['silver', 'lead', 'copper']
# Zinc
# ['zinc']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Barium-Barite
# ['copper', 'barium-barite']
# Minerals:  ['copper', 'gold', 'silver', 'barium-barite']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Lead
# ['silver', 'lead']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite', 'silver', 'lead']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Lead
# ['lead']
# Minerals:  ['lead', 'barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Lead
# ['copper', 'lead']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Uranium
# ['uranium']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'uranium']
#
# ***
#
# Gold
# ['gold']
# Lead, Zinc
# ['lead', 'zinc']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold', 'zinc', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Manganese
# ['manganese']
# Minerals:  ['manganese', 'copper', 'gold', 'lead', 'silver']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Copper
# ['copper']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Zinc, Lead
# ['zinc', 'lead']
# Copper, Barium-Barite
# ['copper', 'barium-barite']
# Minerals:  ['barium-barite', 'copper', 'lead', 'silver', 'zinc']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver, Gold, Lead
# ['silver', 'gold', 'lead']
# Zinc, Copper, Barium-Barite
# ['zinc', 'copper', 'barium-barite']
# Minerals:  ['barium-barite', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper, Silver, Lead, Zinc
# ['copper', 'silver', 'lead', 'zinc']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Lead
# ['lead']
# Silver, Copper
# ['silver', 'copper']
# Minerals:  ['copper', 'silver', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Silver, Copper
# ['silver', 'copper']
# Minerals:  ['silver', 'zinc', 'copper', 'lead']
#
# ***
#
# Silver
# ['silver']
# Zinc, Lead
# ['zinc', 'lead']
# Gold
# ['gold']
# Minerals:  ['lead', 'gold', 'silver', 'zinc']
#
# ***
#
# Uranium
# ['uranium']
# Silver, Gold
# ['silver', 'gold']
# Molybdenum
# ['molybdenum']
# Minerals:  ['silver', 'gold', 'molybdenum', 'uranium']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper
# ['copper']
# Minerals:  ['copper', 'tungsten']
#
# ***
#
# Iron, Tungsten
# ['iron', 'tungsten']
# Minerals:  ['iron', 'tungsten']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Zinc
# ['copper', 'zinc']
# Antimony
# ['antimony']
# Minerals:  ['copper', 'gold', 'antimony', 'silver', 'zinc']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Antimony
# ['antimony']
# Minerals:  ['lead', 'copper', 'antimony', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Copper
# ['copper']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Copper, Zinc, Lead
# ['copper', 'zinc', 'lead']
# Gold
# ['gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead, Copper, Zinc
# ['lead', 'copper', 'zinc']
# Gold
# ['gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Lead, Zinc, Copper
# ['silver', 'lead', 'zinc', 'copper']
# Gold
# ['gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Molybdenum
# ['molybdenum']
# Minerals:  ['molybdenum', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Molybdenum
# ['molybdenum']
# Minerals:  ['molybdenum', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten, Copper
# ['tungsten', 'copper']
# Minerals:  ['copper', 'tungsten']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Copper, Silver, Gold
# ['copper', 'silver', 'gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper
# ['copper']
# Molybdenum
# ['molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Gold
# ['gold']
# Tungsten, Copper
# ['tungsten', 'copper']
# Minerals:  ['copper', 'gold', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper
# ['copper']
# Minerals:  ['copper', 'tungsten']
#
# ***
#
# Tungsten, Molybdenum
# ['tungsten', 'molybdenum']
# Copper
# ['copper']
# Minerals:  ['copper', 'molybdenum', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Molybdenum, Gold
# ['molybdenum', 'gold']
# Minerals:  ['gold', 'molybdenum']
#
# ***
#
# Tungsten
# ['tungsten']
# Gold, Barium-Barite
# ['gold', 'barium-barite']
# Minerals:  ['gold', 'barium-barite', 'tungsten']
#
# ***
#
# Molybdenum, Tungsten, Copper
# ['molybdenum', 'tungsten', 'copper']
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['molybdenum', 'tungsten', 'copper', 'gold', 'silver']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Sodium, Cobalt, Gypsum-Anhydrite
# ['sodium', 'cobalt', 'gypsum-anhydrite']
# Minerals:  ['cobalt', 'gypsum-anhydrite', 'sodium']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Gold
# ['gold']
# Lead, Iron
# ['lead', 'iron']
# Minerals:  ['gold', 'iron', 'lead']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Bromine, Halite
# ['bromine', 'halite']
# Minerals:  ['bromine', 'halite']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Iron, Silver, Calcium
# ['iron', 'silver', 'calcium']
# Minerals:  ['silver', 'calcium', 'iron', 'fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Beryllium
# ['beryllium']
# Minerals:  ['beryllium']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Gold
# ['gold']
# Silver, Lead, Copper
# ['silver', 'lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Tungsten, Gold
# ['tungsten', 'gold']
# Silver
# ['silver']
# Minerals:  ['gold', 'silver', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper
# ['copper']
# Uranium
# ['uranium']
# Minerals:  ['copper', 'uranium', 'tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper, Molybdenum, Tungsten
# ['copper', 'molybdenum', 'tungsten']
# Minerals:  ['copper', 'molybdenum', 'tungsten']
#
# ***
#
# Gold
# ['gold']
# Tungsten
# ['tungsten']
# Minerals:  ['gold', 'tungsten']
#
# ***
#
# Zinc, Silver
# ['zinc', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Gold, Tungsten
# ['gold', 'tungsten']
# Minerals:  ['tungsten', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Lead, Copper
# ['silver', 'lead', 'copper']
# Zinc
# ['zinc']
# Gold, Molybdenum
# ['gold', 'molybdenum']
# Minerals:  ['molybdenum', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Lead
# ['lead']
# Zinc, Copper
# ['zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Zinc, Molybdenum
# ['zinc', 'molybdenum']
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['molybdenum', 'zinc', 'fluorine-fluorite', 'tungsten']
#
# ***
#
# Silver
# ['silver']
# Lead
# ['lead']
# Zinc, Copper
# ['zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Uranium
# ['uranium']
# Lead, Zinc, Copper, Barium-Barite
# ['lead', 'zinc', 'copper', 'barium-barite']
# Minerals:  ['barium-barite', 'copper', 'lead', 'uranium', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead
# ['lead']
# Zinc, Copper
# ['zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Zinc, Copper
# ['zinc', 'copper']
# Silver
# ['silver']
# Lead, Tungsten, Molybdenum, Bismuth, Nickel
# ['lead', 'tungsten', 'molybdenum', 'bismuth', 'nickel']
# Minerals:  ['molybdenum', 'nickel', 'tungsten', 'bismuth', 'copper', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper, Lead, Zinc
# ['copper', 'lead', 'zinc']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Boron-Borates
# ['boron-borates']
# Minerals:  ['boron-borates']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Silver
# ['silver']
# Zinc, Lead, Copper
# ['zinc', 'lead', 'copper']
# Minerals:  ['lead', 'silver', 'copper', 'zinc']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead, Copper, Zinc
# ['lead', 'copper', 'zinc']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Lead
# ['lead']
# Zinc
# ['zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Boron-Borates
# ['boron-borates']
# Zeolites
# ['zeolites']
# Minerals:  ['boron-borates', 'zeolites']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Gold
# ['gold']
# Tungsten
# ['tungsten']
# Minerals:  ['gold', 'tungsten']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Lead
# ['copper', 'lead']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Molybdenum, Copper
# ['molybdenum', 'copper']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Silver
# ['silver']
# Copper
# ['copper']
# Minerals:  ['copper', 'silver']
#
# ***
#
# Silver
# ['silver']
# Copper
# ['copper']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['copper', 'silver', 'barium-barite']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc
# ['lead', 'zinc']
# Gold, Barium-Barite
# ['gold', 'barium-barite']
# Minerals:  ['barium-barite', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Zinc, Lead, Silver
# ['zinc', 'lead', 'silver']
# Copper
# ['copper']
# Gold, Manganese
# ['gold', 'manganese']
# Minerals:  ['manganese', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Zinc, Lead, Copper
# ['zinc', 'lead', 'copper']
# Minerals:  ['lead', 'copper', 'zinc']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Silver, Lead
# ['silver', 'lead']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold', 'silver']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Gold
# ['gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Lead
# ['copper', 'lead']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['gold', 'zinc', 'silver', 'lead']
#
# ***
#
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Tungsten
# ['tungsten']
# Copper, Molybdenum, Iron, Zinc
# ['copper', 'molybdenum', 'iron', 'zinc']
# Minerals:  ['molybdenum', 'iron', 'tungsten', 'copper', 'zinc']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper
# ['copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'iron']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite', 'copper', 'lead', 'silver', 'zinc']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Zinc, Lead, Copper
# ['zinc', 'lead', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Copper
# ['copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Copper, Gold
# ['copper', 'gold']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Copper, Lead, Zinc
# ['copper', 'lead', 'zinc']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Gold
# ['gold']
# Minerals:  ['gold', 'zinc', 'silver', 'lead']
#
# ***
#
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Gold, Copper
# ['gold', 'copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Copper, Gold
# ['copper', 'gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Copper, Zinc
# ['lead', 'copper', 'zinc']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Graphite
# ['graphite']
# Minerals:  ['graphite']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Tungsten
# ['tungsten']
# Molybdenum
# ['molybdenum']
# Minerals:  ['molybdenum', 'tungsten']
#
# ***
#
# Copper, Molybdenum
# ['copper', 'molybdenum']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Gold
# ['gold']
# Zinc, Copper
# ['zinc', 'copper']
# Minerals:  ['copper', 'gold', 'zinc']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony, Gold
# ['antimony', 'gold']
# Minerals:  ['gold', 'antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Silver, Antimony
# ['silver', 'antimony']
# Gold
# ['gold']
# Minerals:  ['gold', 'silver', 'antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Antimony
# ['antimony']
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver', 'antimony']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Antimony, Silver
# ['antimony', 'silver']
# Minerals:  ['silver', 'antimony']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Antimony, Gold
# ['antimony', 'gold']
# Minerals:  ['gold', 'antimony']
#
# ***
#
# Vermiculite
# ['vermiculite']
# Copper
# ['copper']
# Minerals:  ['vermiculite', 'copper']
#
# ***
#
# Silica, Quartz
# ['silica', 'quartz']
# Minerals:  ['quartz', 'silica']
#
# ***
#
# Gold
# ['gold']
# Copper, Tungsten
# ['copper', 'tungsten']
# Minerals:  ['copper', 'gold', 'tungsten']
#
# ***
#
# Molybdenum
# ['molybdenum']
# Minerals:  ['molybdenum']
#
# ***
#
# Quartz
# ['quartz']
# Minerals:  ['quartz']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Calcium
# ['calcium']
# Minerals:  ['calcium']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Magnesite
# ['magnesite']
# Minerals:  ['magnesite']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Tungsten
# ['tungsten']
# Minerals:  ['tungsten']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Gold
# ['gold']
# Minerals:  ['gold', 'zinc', 'silver', 'lead']
#
# ***
#
# Silver
# ['silver']
# Lead, Zinc, Copper
# ['lead', 'zinc', 'copper']
# Minerals:  ['copper', 'zinc', 'silver', 'lead']
#
# ***
#
# Stone, Crushed/Broken
# ['stone', 'crushed/broken']
# Minerals:  ['crushed/broken', 'stone']
#
# ***
#
# Molybdenum, Copper
# ['molybdenum', 'copper']
# Silver
# ['silver']
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['molybdenum', 'copper', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Graphite, Silica
# ['graphite', 'silica']
# Minerals:  ['graphite', 'silica', 'manganese']
#
# ***
#
# Iron
# ['iron']
# Phosphorus-Phosphates, Sulfur
# ['phosphorus-phosphates', 'sulfur']
# Minerals:  ['phosphorus-phosphates', 'iron', 'sulfur']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Sulfur, Phosphorus-Phosphates
# ['sulfur', 'phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates', 'sulfur', 'iron']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Iron
# ['iron']
# Minerals:  ['iron']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper
# ['copper']
# Zinc
# ['zinc']
# Lead
# ['lead']
# Minerals:  ['copper', 'lead', 'zinc']
#
# ***
#
# Copper, Silver
# ['copper', 'silver']
# Gold
# ['gold']
# Zinc
# ['zinc']
# ...
#
# Clay, Kaolin
# ['clay', 'kaolin']
# Stone
# ['stone']
# Minerals:  ['clay', 'stone', 'kaolin']
#
# ***
#
# Gemstone, Kaolin
# ['gemstone', 'kaolin']
# Minerals:  ['gemstone', 'kaolin']
#
# ***
#
# Tin, Silver, Gold
# ['tin', 'silver', 'gold']
# Mercury, Phosphorus-Phosphates
# ['mercury', 'phosphorus-phosphates']
# Minerals:  ['tin', 'gold', 'phosphorus-phosphates', 'mercury', 'silver']
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Tin
# ['tin']
# Minerals:  ['tin']
#
# ***
#
# Kaolin
# ['kaolin']
# Minerals:  ['kaolin']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Copper, Zinc, Lead
# ['copper', 'zinc', 'lead']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silica, Feldspar, Gemstone
# ['silica', 'feldspar', 'gemstone']
# Minerals:  ['feldspar', 'silica', 'gemstone']
#
# ***
#
# Tin, Silver, Lead, Gold
# ['tin', 'silver', 'lead', 'gold']
# Minerals:  ['silver', 'gold', 'tin', 'lead']
#
# ***
#
# Gold, Copper, Zinc, Silver, Lead
# ['gold', 'copper', 'zinc', 'silver', 'lead']
# Antimony
# ['antimony']
# Minerals:  ['antimony', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Zinc, Lead
# ['silver', 'zinc', 'lead']
# Copper, Gold
# ['copper', 'gold']
# Mercury, Tin
# ['mercury', 'tin']
# Minerals:  ['tin', 'copper', 'gold', 'lead', 'mercury', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Mercury
# ['mercury']
# Minerals:  ['mercury', 'silver']
#
# ***
#
# Mercury, Antimony
# ['mercury', 'antimony']
# Sulfur
# ['sulfur']
# Minerals:  ['mercury', 'sulfur', 'antimony']
#
# ***
#
# Antimony, Mercury
# ['antimony', 'mercury']
# Sulfur
# ['sulfur']
# Minerals:  ['mercury', 'sulfur', 'antimony']
#
# ***
#
# Antimony, Mercury
# ['antimony', 'mercury']
# Sulfur
# ['sulfur']
# Minerals:  ['mercury', 'sulfur', 'antimony']
#
# ***
#
# Mercury, Copper
# ['mercury', 'copper']
# Minerals:  ['copper', 'mercury']
#
# ***
#
# Mercury
# ['mercury']
# Copper
# ['copper']
# Minerals:  ['copper', 'mercury']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Silver, Gold, Lead
# ['silver', 'gold', 'lead']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold', 'silver', 'lead']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['lead', 'zinc']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Lead, Copper
# ['lead', 'copper']
# Minerals:  ['lead', 'copper', 'fluorine-fluorite', 'barium-barite']
#
# ***
#
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite']
#
# ***
#
# Mercury
# ['mercury']
# Strontium, Zinc, Barium-Barite, Nickel, Lead, Zirconium, Copper, Arsenic
# ['strontium', 'zinc', 'barium-barite', 'nickel', 'lead', 'zirconium', 'copper', 'arsenic']
# Minerals:  ['strontium', 'nickel', 'zirconium', 'barium-barite', 'copper', 'arsenic', 'lead', 'mercury', 'zinc']
#
# ***
#
# Mercury, Antimony
# ['mercury', 'antimony']
# Minerals:  ['mercury', 'antimony']
#
# ***
#
# Antimony, Mercury, Zinc, Lead, Silver, Tin, Gold
# ['antimony', 'mercury', 'zinc', 'lead', 'silver', 'tin', 'gold']
# Minerals:  ['tin', 'antimony', 'gold', 'lead', 'mercury', 'silver', 'zinc']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Silver, Mercury, Tin, Gold
# ['silver', 'mercury', 'tin', 'gold']
# Minerals:  ['mercury', 'tin', 'silver', 'gold']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Silver, Lead
# ['silver', 'lead']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Iron, Copper
# ['iron', 'copper']
# Lead, Arsenic, Molybdenum
# ['lead', 'arsenic', 'molybdenum']
# Minerals:  ['molybdenum', 'iron', 'arsenic', 'copper', 'lead']
#
# ***
#
# Zinc, Silver, Lead
# ['zinc', 'silver', 'lead']
# Minerals:  ['lead', 'silver', 'zinc']
#
# ***
#
# Talc-Soapstone, Asbestos
# ['talc-soapstone', 'asbestos']
# Minerals:  ['talc-soapstone', 'asbestos']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Mercury
# ['mercury']
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['mercury', 'silver', 'gold']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Copper, Lead, Zinc, Silver
# ['copper', 'lead', 'zinc', 'silver']
# Minerals:  ['copper', 'silver', 'zinc', 'lead']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['lead', 'zinc']
#
# ***
#
# Lead, Silver, Zinc
# ['lead', 'silver', 'zinc']
# Minerals:  ['zinc', 'silver', 'lead']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Perlite, Stone, Crushed/Broken
# ['perlite', 'stone', 'crushed/broken']
# Minerals:  ['crushed/broken', 'perlite', 'stone']
#
# ***
#
# Stone, Crushed/Broken, Fluorine-Fluorite
# ['stone', 'crushed/broken', 'fluorine-fluorite']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite, Stone, Crushed/Broken
# ['fluorine-fluorite', 'stone', 'crushed/broken']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Stone, Crushed/Broken, Fluorine-Fluorite
# ['stone', 'crushed/broken', 'fluorine-fluorite']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Antimony
# ['antimony']
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver', 'antimony']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite, Stone, Crushed/Broken
# ['fluorine-fluorite', 'stone', 'crushed/broken']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Stone, Crushed/Broken, Fluorine-Fluorite
# ['stone', 'crushed/broken', 'fluorine-fluorite']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Zinc, Gold, Copper, Silver, Lead
# ['zinc', 'gold', 'copper', 'silver', 'lead']
# Thorium, Arsenic, Antimony
# ['thorium', 'arsenic', 'antimony']
# Minerals:  ['thorium', 'antimony', 'arsenic', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Copper
# ['copper']
# Iron
# ['iron']
# Minerals:  ['copper', 'iron']
#
# ***
#
# Lead, Zinc, Silver
# ['lead', 'zinc', 'silver']
# Tin, Gold, Copper, Vanadium
# ['tin', 'gold', 'copper', 'vanadium']
# Minerals:  ['tin', 'vanadium', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Zinc, Silver, Lead
# ['zinc', 'silver', 'lead']
# Copper, Gold
# ['copper', 'gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Lead, Silver
# ['lead', 'silver']
# Minerals:  ['silver', 'lead']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Stone, Crushed/Broken, Fluorine-Fluorite
# ['stone', 'crushed/broken', 'fluorine-fluorite']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Stone, Crushed/Broken, Fluorine-Fluorite
# ['stone', 'crushed/broken', 'fluorine-fluorite']
# Minerals:  ['crushed/broken', 'stone', 'fluorine-fluorite']
#
# ***
#
# Lead, Zinc, Silver, Dolomite
# ['lead', 'zinc', 'silver', 'dolomite']
# Minerals:  ['silver', 'dolomite', 'zinc', 'lead']
#
# ***
#
# Stone, Crushed/Broken
# ['stone', 'crushed/broken']
# Minerals:  ['crushed/broken', 'stone']
#
# ***
#
# Sand and Gravel, Construction
# ['sandandgravel', 'construction']
# Minerals:  ['construction', 'sandandgravel']
#
# ***
#
# Sand and Gravel, Construction
# ['sandandgravel', 'construction']
# Minerals:  ['construction', 'sandandgravel']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Gold
# ['gold']
# Minerals:  ['gold']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Lead, Barium-Barite
# ['lead', 'barium-barite']
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['barium-barite', 'fluorine-fluorite', 'lead']
#
# ***
#
# Barium-Barite, Gypsum-Anhydrite
# ['barium-barite', 'gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite', 'barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Minerals:  ['barium-barite']
#
# ***
#
# Barium-Barite
# ['barium-barite']
# Gypsum-Anhydrite, Fluorine-Fluorite
# ['gypsum-anhydrite', 'fluorine-fluorite']
# Minerals:  ['gypsum-anhydrite', 'fluorine-fluorite', 'barium-barite']
#
# ***
#
# Sand and Gravel, Construction, Barium-Barite
# ['sandandgravel', 'construction', 'barium-barite']
# Minerals:  ['construction', 'barium-barite', 'sandandgravel']
#
# ***
#
# Barium-Barite, Gypsum-Anhydrite
# ['barium-barite', 'gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite', 'barium-barite']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Copper, Silver, Zinc, Lead
# ['copper', 'silver', 'zinc', 'lead']
# Minerals:  ['copper', 'silver', 'lead', 'zinc']
#
# ***
#
# Bentonite
# ['bentonite']
# Kaolin
# ['kaolin']
# Minerals:  ['bentonite', 'kaolin']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Bentonite
# ['bentonite']
# Minerals:  ['bentonite']
#
# ***
#
# Coal
# ['coal']
# Graphite
# ['graphite']
# Minerals:  ['graphite', 'coal']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Brick Clay
# ['brickclay']
# Minerals:  ['brickclay']
#
# ***
#
# Brick Clay
# ['brickclay']
# Minerals:  ['brickclay']
#
# ***
#
# Clay
# ['clay']
# Minerals:  ['clay']
#
# ***
#
# Brick Clay
# ['brickclay']
# Minerals:  ['brickclay']
#
# ***
#
# Stone, Crushed/Broken, Clay
# ['stone', 'crushed/broken', 'clay']
# Sand and Gravel, Construction
# ['sandandgravel', 'construction']
# Minerals:  ['clay', 'stone', 'sandandgravel', 'crushed/broken', 'construction']
#
# ***
#
# Coal
# ['coal']
# Minerals:  ['coal']
#
# ***
#
# Copper
# ['copper']
# Minerals:  ['copper']
#
# ***
#
# Halite
# ['halite']
# Minerals:  ['halite']
#
# ***
#
# Halite
# ['halite']
# Minerals:  ['halite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Gypsum-Anhydrite
# ['gypsum-anhydrite']
# Minerals:  ['gypsum-anhydrite', 'fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Halite
# ['halite']
# Minerals:  ['halite']
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Halite
# ['halite']
# Minerals:  ['halite']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['lead', 'zinc']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Minerals:  ['lead', 'zinc']
#
# ***
#
# Zinc, Lead
# ['zinc', 'lead']
# Barium-Barite
# ['barium-barite']
# Minerals:  ['lead', 'barium-barite', 'zinc']
#
# ***
#
# Lead, Zinc
# ['lead', 'zinc']
# Minerals:  ['zinc', 'lead']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Mercury
# ['mercury']
# Antimony, Sulfur
# ['antimony', 'sulfur']
# Minerals:  ['mercury', 'sulfur', 'antimony']
#
# ***
#
# Mercury
# ['mercury']
# Gold
# ['gold']
# Copper
# ['copper']
# Minerals:  ['copper', 'mercury', 'gold']
#
# ***
#
# Gold, Silver, Fluorine-Fluorite
# ['gold', 'silver', 'fluorine-fluorite']
# Minerals:  ['gold', 'silver', 'fluorine-fluorite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Antimony
# ['antimony']
# Minerals:  ['antimony']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Tin
# ['tin']
# Minerals:  ['tin']
#
# ***
#
# Marble, Dimension
# ['marble', 'dimension']
# Minerals:  ['marble', 'dimension']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Gold, Silver, Zinc, Lead
# ['gold', 'silver', 'zinc', 'lead']
# Copper
# ['copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Zinc
# ['zinc']
# Minerals:  ['zinc']
#
# ***
#
# Lead, Zinc, Silver
# ['lead', 'zinc', 'silver']
# Copper, Gold
# ['copper', 'gold']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Minerals:  ['gold', 'silver']
#
# ***
#
# Zinc, Silver, Lead
# ['zinc', 'silver', 'lead']
# Gold, Copper
# ['gold', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Zinc, Silver, Lead
# ['zinc', 'silver', 'lead']
# Gold, Copper
# ['gold', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Mercury
# ['mercury']
# Iron
# ['iron']
# Minerals:  ['mercury', 'iron']
#
# ***
#
# Mercury
# ['mercury']
# Lead, Gold, Copper, Silver
# ['lead', 'gold', 'copper', 'silver']
# Minerals:  ['copper', 'gold', 'lead', 'mercury', 'silver']
#
# ***
#
# Minerals:  []
#
# ***
#
# Phosphorus-Phosphates
# ['phosphorus-phosphates']
# Minerals:  ['phosphorus-phosphates']
#
# ***
#
# Wollastonite
# ['wollastonite']
# Silver, Zinc, Lead
# ['silver', 'zinc', 'lead']
# Minerals:  ['lead', 'zinc', 'silver', 'wollastonite']
#
# ***
#
# Mercury
# ['mercury']
# Silver, Gold
# ['silver', 'gold']
# Minerals:  ['mercury', 'silver', 'gold']
#
# ***
#
# Tin
# ['tin']
# Minerals:  ['tin']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Tin
# ['tin']
# Minerals:  ['gold', 'tin', 'silver']
#
# ***
#
# Gold, Zinc, Lead, Copper
# ['gold', 'zinc', 'lead', 'copper']
# Minerals:  ['lead', 'gold', 'copper', 'zinc']
#
# ***
#
# Tin
# ['tin']
# Minerals:  ['tin']
#
# ***
#
# Clay, Kaolin
# ['clay', 'kaolin']
# Minerals:  ['clay', 'kaolin']
#
# ***
#
# Mercury, Copper, Silver
# ['mercury', 'copper', 'silver']
# Minerals:  ['copper', 'mercury', 'silver']
#
# ***
#
# Lead, Zinc, Mercury, Copper
# ['lead', 'zinc', 'mercury', 'copper']
# Minerals:  ['copper', 'mercury', 'zinc', 'lead']
#
# ***
#
# Kaolin
# ['kaolin']
# Minerals:  ['kaolin']
#
# ***
#
# Clay, Kaolin
# ['clay', 'kaolin']
# Minerals:  ['clay', 'kaolin']
#
# ***
#
# Lead, Gold, Silver
# ['lead', 'gold', 'silver']
# Antimony, Zinc
# ['antimony', 'zinc']
# Minerals:  ['lead', 'gold', 'antimony', 'silver', 'zinc']
#
# ***
#
# Gold, Silver
# ['gold', 'silver']
# Tin
# ['tin']
# Minerals:  ['gold', 'tin', 'silver']
#
# ***
#
# Zinc, Gold, Lead, Silver, Copper
# ['zinc', 'gold', 'lead', 'silver', 'copper']
# Kaolin, Tin
# ['kaolin', 'tin']
# Minerals:  ['tin', 'kaolin', 'copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Gemstone
# ['gemstone']
# Minerals:  ['gemstone']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['fluorine-fluorite']
#
# ***
#
# Beryllium, Fluorine-Fluorite, Mercury
# ['beryllium', 'fluorine-fluorite', 'mercury']
# Minerals:  ['beryllium', 'fluorine-fluorite', 'mercury']
#
# ***
#
# Tin
# ['tin']
# Minerals:  ['tin']
#
# ***
#
# Mercury
# ['mercury']
# Minerals:  ['mercury']
#
# ***
#
# Gemstone
# ['gemstone']
# Minerals:  ['gemstone']
#
# ***
#
# Silver, Gold
# ['silver', 'gold']
# Zinc, Lead, Copper
# ['zinc', 'lead', 'copper']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']
#
# ***
#
# Mercury, Gemstone
# ['mercury', 'gemstone']
# Minerals:  ['mercury', 'gemstone']
#
# ***
#
# Silver, Gold, Lead
# ['silver', 'gold', 'lead']
# Antimony, Zinc
# ['antimony', 'zinc']
# Minerals:  ['lead', 'gold', 'antimony', 'silver', 'zinc']
#
# ***
#
# Silver
# ['silver']
# Minerals:  ['silver']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Strontium, Barium-Barite
# ['strontium', 'barium-barite']
# Minerals:  ['strontium', 'fluorine-fluorite', 'barium-barite']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# REE, Strontium
# ['ree', 'strontium']
# Minerals:  ['ree', 'strontium', 'fluorine-fluorite']
#
# ***
#
# Silver, Lead, Zinc
# ['silver', 'lead', 'zinc']
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Minerals:  ['zinc', 'silver', 'fluorine-fluorite', 'lead']
#
# ***
#
# Fluorine-Fluorite
# ['fluorine-fluorite']
# Calcium, Quartz, Barium-Barite
# ['calcium', 'quartz', 'barium-barite']
# Minerals:  ['quartz', 'calcium', 'fluorine-fluorite', 'barium-barite']
#
# ***
#
# Molybdenum, Copper
# ['molybdenum', 'copper']
# Minerals:  ['copper', 'molybdenum']
#
# ***
#
# Manganese
# ['manganese']
# Minerals:  ['manganese']
#
# ***
#
# Copper, Gold, Silver, Lead, Zinc
# ['copper', 'gold', 'silver', 'lead', 'zinc']
# Minerals:  ['copper', 'gold', 'lead', 'silver', 'zinc']

# %% [markdown]
# ## Export JSON Object

# %%
print("Sample Feature Object:\n\n",json_obj['features'][0])
# Out:
# Sample Feature Object:
#
#  {'type': 'Feature', 'properties': {'dep_id': 10008155, 'url': 'https://mrdata.usgs.gov/mrds/show-mrds.php?dep_id=10008155', 'mrds_id': 'D000119', 'mas_id': None, 'site_name': 'Oruro Mine Cuchillo Parado Dist.', 'latitude': 29.33356, 'longitude': -104.91717, 'region': None, 'country': 'Mexico', 'state': 'Chihuahua', 'county': None, 'com_type': 'M', 'commod1': 'Copper, Gold, Silver, Vanadium', 'commod2': None, 'commod3': None, 'oper_type': 'Unknown', 'dep_type': None, 'prod_size': 'N', 'dev_stat': 'Occurrence', 'ore': None, 'gangue': None, 'other_matl': None, 'orebody_fm': None, 'work_type': None, 'model': None, 'alteration': None, 'conc_proc': None, 'names': None, 'ore_ctrl': None, 'reporter': 'Fischer, Richard P.', 'hrock_unit': None, 'hrock_type': None, 'arock_unit': None, 'arock_type': None, 'structure': None, 'tectonic': None, 'ref': 'GONZALEZ REYNA, J., 1956-SEE USGS BULL. 1316, REF. NO. 00108', 'yfp_ba': None, 'yr_fst_prd': None, 'ylp_ba': None, 'yr_lst_prd': None, 'dy_ba': None, 'disc_yr': None, 'prod_yrs': None, 'discr': None, 'mineral_tags': ['copper', 'gold', 'silver', 'vanadium']}, 'geometry': {'type': 'Point', 'coordinates': [-104.91717, 29.33356]}}

# %%
output = open("mexico_tags.json", 'w')

output.write(json.dumps(json_obj, indent=2))

output.close()
